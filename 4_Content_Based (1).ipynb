# %% [markdown]
# # Movies and tags data loading

# %%
#importing the relevant python libraries
import pandas as pd
import numpy as np

# %%
#Loading the movies csv file into a dataframe
movies_df = pd.read_csv('movies.csv',usecols=['movieId','title','genres'],
                        dtype={'movieId': 'int32', 'title': 'str', 'genres': 'str'})
movies_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
#Loading the genome relevance score csv file into a dataframe
genome_scores_df = pd.read_csv('Genome-scores.csv')
genome_scores_df
# Out:
#          movieId  tag_id  relevance
# 0              1       1   0.500891
# 1              2       1   0.499823
# 2              3       1   0.499874
# 3              5       1   0.499875
# 4              7       1   0.499911
# ...          ...     ...        ...
# 2293543   183611    1459   0.499725
# 2293544   184471    1459   0.499719
# 2293545   187593    1459   0.499717
# 2293546   187595    1459   0.499768
# 2293547   193565    1459   0.499679
#
# [2293548 rows x 3 columns]

# %%
#Merging the relevance score and movies dataframes
merge_df = pd.merge(genome_scores_df,movies_df,on='movieId')
merge_df
# Out:
#          movieId  tag_id  relevance                      title  \
# 0              1       1   0.500891           Toy Story (1995)
# 1              1       2   0.499961           Toy Story (1995)
# 2              1       3   0.499807           Toy Story (1995)
# 3              1       4   0.499736           Toy Story (1995)
# 4              1       5   0.499736           Toy Story (1995)
# ...          ...     ...        ...                        ...
# 2293543   193565    1455   0.499331  Gintama: The Movie (2010)
# 2293544   193565    1456   0.499623  Gintama: The Movie (2010)
# 2293545   193565    1457   0.499331  Gintama: The Movie (2010)
# 2293546   193565    1458   0.499527  Gintama: The Movie (2010)
# 2293547   193565    1459   0.499679  Gintama: The Movie (2010)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2        Adventure|Animation|Children|Comedy|Fantasy
# 3        Adventure|Animation|Children|Comedy|Fantasy
# 4        Adventure|Animation|Children|Comedy|Fantasy
# ...                                              ...
# 2293543               Action|Animation|Comedy|Sci-Fi
# 2293544               Action|Animation|Comedy|Sci-Fi
# 2293545               Action|Animation|Comedy|Sci-Fi
# 2293546               Action|Animation|Comedy|Sci-Fi
# 2293547               Action|Animation|Comedy|Sci-Fi
#
# [2293548 rows x 5 columns]

# %%
## Creating a Pivot matrix
final_tag_relevance_df = merge_df.pivot_table(index='title',columns='tag_id',values='relevance').fillna(0)
final_tag_relevance_df
# Out:
# tag_id                                 1         2         3         4     \
# title
# (500) Days of Summer (2009)        0.509666  0.502885  0.504418  0.499448
# ...And Justice for All (1979)      0.499911  0.499954  0.499855  0.499802
# 10 Cloverfield Lane (2016)         0.499877  0.499961  0.499796  0.499721
# 10 Things I Hate About You (1999)  0.499911  0.499954  0.499855  0.499802
# 101 Dalmatians (1996)              0.499875  0.499935  0.499796  0.499721
# ...                                     ...       ...       ...       ...
# Zero Dark Thirty (2012)            0.499804  0.499899  0.499680  0.499563
# Zombieland (2009)                  0.509602  0.502937  0.503271  0.499526
# Zoolander (2001)                   0.502911  0.505838  0.543560  0.499522
# Zulu (1964)                        0.499911  0.499954  0.499855  0.499802
# eXistenZ (1999)                    0.499911  0.499954  0.499855  0.499802
#
# tag_id                                 5         6         7         8     \
# title
# (500) Days of Summer (2009)        0.499448  0.499648  0.499763  0.500419
# ...And Justice for All (1979)      0.499802  0.499874  0.499880  0.499907
# 10 Cloverfield Lane (2016)         0.499721  0.499822  0.499844  0.502242
# 10 Things I Hate About You (1999)  0.499802  0.499874  0.499880  0.499907
# 101 Dalmatians (1996)              0.499721  0.499822  0.499830  0.499869
# ...                                     ...       ...       ...       ...
# Zero Dark Thirty (2012)            0.499563  0.499721  0.499734  0.499795
# Zombieland (2009)                  0.499526  0.499697  0.500196  0.499946
# Zoolander (2001)                   0.499522  0.499695  0.499759  0.499775
# Zulu (1964)                        0.499802  0.499874  0.499880  0.503074
# eXistenZ (1999)                    0.499802  0.499874  0.499880  0.499907
#
# tag_id                                 9         10    ...      1450  \
# title                                                  ...
# (500) Days of Summer (2009)        0.499702  0.499740  ...  0.500109
# ...And Justice for All (1979)      0.499893  0.499907  ...  0.499957
# 10 Cloverfield Lane (2016)         0.502760  0.514212  ...  0.499939
# 10 Things I Hate About You (1999)  0.499893  0.499907  ...  0.499957
# 101 Dalmatians (1996)              0.504808  0.499868  ...  0.499939
# ...                                     ...       ...  ...       ...
# Zero Dark Thirty (2012)            0.499764  0.499794  ...  0.500355
# Zombieland (2009)                  0.499744  0.499776  ...  0.500697
# Zoolander (2001)                   0.499742  0.499774  ...  0.499896
# Zulu (1964)                        0.499893  0.499907  ...  0.499957
# eXistenZ (1999)                    0.499893  0.499907  ...  0.499957
#
# tag_id                                 1451      1452      1453      1454  \
# title
# (500) Days of Summer (2009)        0.500109  0.500109  0.499042  0.499664
# ...And Justice for All (1979)      0.499957  0.499957  0.499657  0.499880
# 10 Cloverfield Lane (2016)         0.499939  0.499939  0.499516  0.499830
# 10 Things I Hate About You (1999)  0.499957  0.499957  0.499657  0.499880
# 101 Dalmatians (1996)              0.499939  0.499939  0.499516  0.499830
# ...                                     ...       ...       ...       ...
# Zero Dark Thirty (2012)            0.500355  0.500355  0.499242  0.499734
# Zombieland (2009)                  0.500697  0.500697  0.499178  0.499712
# Zoolander (2001)                   0.499896  0.499896  0.499170  0.499709
# Zulu (1964)                        0.499957  0.499957  0.499657  0.499880
# eXistenZ (1999)                    0.499957  0.499957  0.499657  0.499880
#
# tag_id                                 1455      1456      1457      1458  \
# title
# (500) Days of Summer (2009)        0.499042  0.499461  0.499042  0.499323
# ...And Justice for All (1979)      0.499657  0.499807  0.499657  0.499758
# 10 Cloverfield Lane (2016)         0.499516  0.499728  0.499516  0.499658
# 10 Things I Hate About You (1999)  0.499657  0.499807  0.499657  0.499758
# 101 Dalmatians (1996)              0.499516  0.499727  0.499516  0.499658
# ...                                     ...       ...       ...       ...
# Zero Dark Thirty (2012)            0.499242  0.499573  0.499242  0.499464
# Zombieland (2009)                  0.499178  0.499537  0.499178  0.499419
# Zoolander (2001)                   0.499170  0.499533  0.499170  0.499414
# Zulu (1964)                        0.499657  0.499807  0.499657  0.499758
# eXistenZ (1999)                    0.499657  0.499807  0.499657  0.499758
#
# tag_id                                 1459
# title
# (500) Days of Summer (2009)        0.499541
# ...And Justice for All (1979)      0.499836
# 10 Cloverfield Lane (2016)         0.499768
# 10 Things I Hate About You (1999)  0.499836
# 101 Dalmatians (1996)              0.499768
# ...                                     ...
# Zero Dark Thirty (2012)            0.499637
# Zombieland (2009)                  0.499606
# Zoolander (2001)                   0.499602
# Zulu (1964)                        0.499836
# eXistenZ (1999)                    0.499836
#
# [1572 rows x 1459 columns]

# %% [markdown]
# # Using the KNN model

# %%
from scipy.sparse import csr_matrix

# %%
final_tag_relevance_df_matrix = csr_matrix(final_tag_relevance_df.values)
final_tag_relevance_df_matrix
# Out:
# <1572x1459 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2293548 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import NearestNeighbors

# %%
model_knn = NearestNeighbors(metric = 'manhattan', algorithm = 'kd_tree')

# %%
import sklearn

# %%
sorted(sklearn.neighbors.VALID_METRICS['kd_tree'])
# Out:
# ['chebyshev',
#  'cityblock',
#  'euclidean',
#  'infinity',
#  'l1',
#  'l2',
#  'manhattan',
#  'minkowski',
#  'p']

# %%
model_knn.fit(final_tag_relevance_df_matrix)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\neighbors\_base.py:413: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# NearestNeighbors(algorithm='kd_tree', leaf_size=30, metric='manhattan',
#                  metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                  radius=1.0)

# %%
final_tag_relevance_df
# Out:
# tag_id                                 1         2         3         4     \
# title
# (500) Days of Summer (2009)        0.509666  0.502885  0.504418  0.499448
# ...And Justice for All (1979)      0.499911  0.499954  0.499855  0.499802
# 10 Cloverfield Lane (2016)         0.499877  0.499961  0.499796  0.499721
# 10 Things I Hate About You (1999)  0.499911  0.499954  0.499855  0.499802
# 101 Dalmatians (1996)              0.499875  0.499935  0.499796  0.499721
# ...                                     ...       ...       ...       ...
# Zero Dark Thirty (2012)            0.499804  0.499899  0.499680  0.499563
# Zombieland (2009)                  0.509602  0.502937  0.503271  0.499526
# Zoolander (2001)                   0.502911  0.505838  0.543560  0.499522
# Zulu (1964)                        0.499911  0.499954  0.499855  0.499802
# eXistenZ (1999)                    0.499911  0.499954  0.499855  0.499802
#
# tag_id                                 5         6         7         8     \
# title
# (500) Days of Summer (2009)        0.499448  0.499648  0.499763  0.500419
# ...And Justice for All (1979)      0.499802  0.499874  0.499880  0.499907
# 10 Cloverfield Lane (2016)         0.499721  0.499822  0.499844  0.502242
# 10 Things I Hate About You (1999)  0.499802  0.499874  0.499880  0.499907
# 101 Dalmatians (1996)              0.499721  0.499822  0.499830  0.499869
# ...                                     ...       ...       ...       ...
# Zero Dark Thirty (2012)            0.499563  0.499721  0.499734  0.499795
# Zombieland (2009)                  0.499526  0.499697  0.500196  0.499946
# Zoolander (2001)                   0.499522  0.499695  0.499759  0.499775
# Zulu (1964)                        0.499802  0.499874  0.499880  0.503074
# eXistenZ (1999)                    0.499802  0.499874  0.499880  0.499907
#
# tag_id                                 9         10    ...      1450  \
# title                                                  ...
# (500) Days of Summer (2009)        0.499702  0.499740  ...  0.500109
# ...And Justice for All (1979)      0.499893  0.499907  ...  0.499957
# 10 Cloverfield Lane (2016)         0.502760  0.514212  ...  0.499939
# 10 Things I Hate About You (1999)  0.499893  0.499907  ...  0.499957
# 101 Dalmatians (1996)              0.504808  0.499868  ...  0.499939
# ...                                     ...       ...  ...       ...
# Zero Dark Thirty (2012)            0.499764  0.499794  ...  0.500355
# Zombieland (2009)                  0.499744  0.499776  ...  0.500697
# Zoolander (2001)                   0.499742  0.499774  ...  0.499896
# Zulu (1964)                        0.499893  0.499907  ...  0.499957
# eXistenZ (1999)                    0.499893  0.499907  ...  0.499957
#
# tag_id                                 1451      1452      1453      1454  \
# title
# (500) Days of Summer (2009)        0.500109  0.500109  0.499042  0.499664
# ...And Justice for All (1979)      0.499957  0.499957  0.499657  0.499880
# 10 Cloverfield Lane (2016)         0.499939  0.499939  0.499516  0.499830
# 10 Things I Hate About You (1999)  0.499957  0.499957  0.499657  0.499880
# 101 Dalmatians (1996)              0.499939  0.499939  0.499516  0.499830
# ...                                     ...       ...       ...       ...
# Zero Dark Thirty (2012)            0.500355  0.500355  0.499242  0.499734
# Zombieland (2009)                  0.500697  0.500697  0.499178  0.499712
# Zoolander (2001)                   0.499896  0.499896  0.499170  0.499709
# Zulu (1964)                        0.499957  0.499957  0.499657  0.499880
# eXistenZ (1999)                    0.499957  0.499957  0.499657  0.499880
#
# tag_id                                 1455      1456      1457      1458  \
# title
# (500) Days of Summer (2009)        0.499042  0.499461  0.499042  0.499323
# ...And Justice for All (1979)      0.499657  0.499807  0.499657  0.499758
# 10 Cloverfield Lane (2016)         0.499516  0.499728  0.499516  0.499658
# 10 Things I Hate About You (1999)  0.499657  0.499807  0.499657  0.499758
# 101 Dalmatians (1996)              0.499516  0.499727  0.499516  0.499658
# ...                                     ...       ...       ...       ...
# Zero Dark Thirty (2012)            0.499242  0.499573  0.499242  0.499464
# Zombieland (2009)                  0.499178  0.499537  0.499178  0.499419
# Zoolander (2001)                   0.499170  0.499533  0.499170  0.499414
# Zulu (1964)                        0.499657  0.499807  0.499657  0.499758
# eXistenZ (1999)                    0.499657  0.499807  0.499657  0.499758
#
# tag_id                                 1459
# title
# (500) Days of Summer (2009)        0.499541
# ...And Justice for All (1979)      0.499836
# 10 Cloverfield Lane (2016)         0.499768
# 10 Things I Hate About You (1999)  0.499836
# 101 Dalmatians (1996)              0.499768
# ...                                     ...
# Zero Dark Thirty (2012)            0.499637
# Zombieland (2009)                  0.499606
# Zoolander (2001)                   0.499602
# Zulu (1964)                        0.499836
# eXistenZ (1999)                    0.499836
#
# [1572 rows x 1459 columns]

# %%
final_tag_relevance_df.shape
# Out:
# (1572, 1459)

# %% [markdown]
# # Already rated movies selection for a user

# %%
rating_df = pd.read_csv('ratings.csv')
rating_df = rating_df.drop('timestamp', axis=1)

# %%
movies_df = pd.read_csv('movies.csv')
movies_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
rating_df = pd.merge(rating_df, movies_df, on='movieId')
rating_df
# Out:
#         userId  movieId  rating                             title  \
# 0            1        1     4.0                  Toy Story (1995)
# 1            5        1     4.0                  Toy Story (1995)
# 2            7        1     4.5                  Toy Story (1995)
# 3           15        1     2.5                  Toy Story (1995)
# 4           17        1     4.5                  Toy Story (1995)
# ...        ...      ...     ...                               ...
# 100831     610   160341     2.5                  Bloodmoon (1997)
# 100832     610   160527     4.5  Sympathy for the Underdog (1971)
# 100833     610   160836     3.0                     Hazard (2005)
# 100834     610   163937     3.5                Blair Witch (2016)
# 100835     610   163981     3.5                         31 (2016)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1       Adventure|Animation|Children|Comedy|Fantasy
# 2       Adventure|Animation|Children|Comedy|Fantasy
# 3       Adventure|Animation|Children|Comedy|Fantasy
# 4       Adventure|Animation|Children|Comedy|Fantasy
# ...                                             ...
# 100831                              Action|Thriller
# 100832                           Action|Crime|Drama
# 100833                        Action|Drama|Thriller
# 100834                              Horror|Thriller
# 100835                                       Horror
#
# [100836 rows x 5 columns]

# %%
rating_df = rating_df.sort_values(['userId', 'rating'], ascending=False).reset_index()
rating_df = rating_df.drop('index',axis=1)
rating_df
# Out:
#         userId  movieId  rating                                         title  \
# 0          610        1     5.0                              Toy Story (1995)
# 1          610        6     5.0                                   Heat (1995)
# 2          610       47     5.0                   Seven (a.k.a. Se7en) (1995)
# 3          610      260     5.0     Star Wars: Episode IV - A New Hope (1977)
# 4          610      296     5.0                           Pulp Fiction (1994)
# ...        ...      ...     ...                                           ...
# 100831       1     2253     2.0                                   Toys (1992)
# 100832       1     2338     2.0  I Still Know What You Did Last Summer (1998)
# 100833       1     2389     2.0                                 Psycho (1998)
# 100834       1     2617     2.0                             Mummy, The (1999)
# 100835       1     3176     1.0               Talented Mr. Ripley, The (1999)
#
#                                                  genres
# 0           Adventure|Animation|Children|Comedy|Fantasy
# 1                                 Action|Crime|Thriller
# 2                                      Mystery|Thriller
# 3                               Action|Adventure|Sci-Fi
# 4                           Comedy|Crime|Drama|Thriller
# ...                                                 ...
# 100831                                   Comedy|Fantasy
# 100832                          Horror|Mystery|Thriller
# 100833                            Crime|Horror|Thriller
# 100834  Action|Adventure|Comedy|Fantasy|Horror|Thriller
# 100835                           Drama|Mystery|Thriller
#
# [100836 rows x 5 columns]

# %%
rating_df = rating_df.set_index(['userId','movieId'])
rating_df
# Out:
#                 rating                                         title  \
# userId movieId
# 610    1           5.0                              Toy Story (1995)
#        6           5.0                                   Heat (1995)
#        47          5.0                   Seven (a.k.a. Se7en) (1995)
#        260         5.0     Star Wars: Episode IV - A New Hope (1977)
#        296         5.0                           Pulp Fiction (1994)
# ...                ...                                           ...
# 1      2253        2.0                                   Toys (1992)
#        2338        2.0  I Still Know What You Did Last Summer (1998)
#        2389        2.0                                 Psycho (1998)
#        2617        2.0                             Mummy, The (1999)
#        3176        1.0               Talented Mr. Ripley, The (1999)
#
#                                                          genres
# userId movieId
# 610    1            Adventure|Animation|Children|Comedy|Fantasy
#        6                                  Action|Crime|Thriller
#        47                                      Mystery|Thriller
#        260                              Action|Adventure|Sci-Fi
#        296                          Comedy|Crime|Drama|Thriller
# ...                                                         ...
# 1      2253                                      Comedy|Fantasy
#        2338                             Horror|Mystery|Thriller
#        2389                               Crime|Horror|Thriller
#        2617     Action|Adventure|Comedy|Fantasy|Horror|Thriller
#        3176                              Drama|Mystery|Thriller
#
# [100836 rows x 3 columns]

# %%
user = 205
rating_df.loc[[user],['rating','title']]
# Out:
#                 rating                                              title
# userId movieId
# 205    71462       5.0                                   Cove, The (2009)
#        260         4.5          Star Wars: Episode IV - A New Hope (1977)
#        6874        4.5                           Kill Bill: Vol. 1 (2003)
#        99114       4.5                            Django Unchained (2012)
#        4896        4.5  Harry Potter and the Sorcerer's Stone (a.k.a. ...
#        81845       4.5                          King's Speech, The (2010)
#        91542       4.5          Sherlock Holmes: A Game of Shadows (2011)
#        179817      4.5                                Darkest Hour (2017)
#        356         4.0                                Forrest Gump (1994)
#        3033        4.0                                  Spaceballs (1987)
#        68157       4.0                        Inglourious Basterds (2009)
#        7153        4.0  Lord of the Rings: The Return of the King, The...
#        8368        4.0    Harry Potter and the Prisoner of Azkaban (2004)
#        69844       4.0      Harry Potter and the Half-Blood Prince (2009)
#        95167       4.0                                       Brave (2012)
#        77561       4.0                                  Iron Man 2 (2010)
#        81834       4.0  Harry Potter and the Deathly Hallows: Part 1 (...
#        88125       4.0  Harry Potter and the Deathly Hallows: Part 2 (...
#        1222        3.5                           Full Metal Jacket (1987)
#        5816        3.5     Harry Potter and the Chamber of Secrets (2002)
#        40815       3.5         Harry Potter and the Goblet of Fire (2005)
#        54001       3.5   Harry Potter and the Order of the Phoenix (2007)
#        1028        3.0                                Mary Poppins (1964)
#        96079       3.0                                     Skyfall (2012)
#        104913      3.0                                        Rush (2013)
#        912         2.5                                  Casablanca (1942)
#        1035        2.5                         Sound of Music, The (1965)

# %%
rated_movies = rating_df.loc[[user],['rating','title']]['title'].tolist()

# %% [markdown]
# # Recommendations

# %%
def recommend(movie):
    s = "title == [ " + "\"" + movie + "\"]"
    distances, indices = model_knn.kneighbors(final_tag_relevance_df.query(s).to_numpy().reshape(1, -1), n_neighbors = 100)
    
    j = 0
    print('Recommendations for {0}:\n'.format(movie))
    for i in range(0, len(distances.flatten())):
        if j >= 5:
            break
        
        if (final_tag_relevance_df.index[indices.flatten()[i]]) in rated_movies:
            continue
        else:
            j += 1
            print('{0}: {1}, with distance of {2}:'.format(i, final_tag_relevance_df.index[indices.flatten()[i]], distances.flatten()[i]))

# %%
movie_list = merge_df['title'].unique().tolist()

# %%
len(movie_list)
# Out:
# 1572

# %%
count = 0
for i in rated_movies:
    if i in movie_list:
        count = count + 1
        print(count)
        recommend(i)
    if count >= 5:
        break
# Out:
# 1
# Recommendations for Star Wars: Episode IV - A New Hope (1977):
#
# 1: Star Wars: Episode V - The Empire Strikes Back (1980), with distance of 1.2478956253613274:
# 2: Star Trek (2009), with distance of 1.2897275781390605:
# 3: Predator (1987), with distance of 1.305212824899476:
# 4: Star Wars: Episode VI - Return of the Jedi (1983), with distance of 1.4226661429499854:
# 5: The Butterfly Effect (2004), with distance of 1.4371769011123223:
# 2
# Recommendations for Kill Bill: Vol. 1 (2003):
#
# 1: Kill Bill: Vol. 2 (2004), with distance of 0.49458918878421776:
# 2: Unforgiven (1992), with distance of 0.49458918878421776:
# 3: Mean Creek (2004), with distance of 0.49458918878421776:
# 4: Fury (1936), with distance of 0.49458918878421776:
# 5: Hero (Ying xiong) (2002), with distance of 0.5298740582067181:
# 3
# Recommendations for Django Unchained (2012):
#
# 1: The Hateful Eight (2015), with distance of 0.9716202789220065:
# 2: Tron: Legacy (2010), with distance of 1.3183153832773913:
# 3: Reservoir Dogs (1992), with distance of 1.3185592187298385:
# 4: John Wick: Chapter Two (2017), with distance of 1.327107957160209:
# 5: Clueless (1995), with distance of 1.3449786861471251:
# 4
# Recommendations for Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001):
#
# 4: Illusionist, The (2006), with distance of 0.6978553146221779:
# 5: Lord of the Rings: The Fellowship of the Ring, The (2001), with distance of 0.7315848418907087:
# 6: Enemy at the Gates (2001), with distance of 1.0543955179599307:
# 7: Lord of the Rings: The Two Towers, The (2002), with distance of 1.0680559202941713:
# 8: Bourne Ultimatum, The (2007), with distance of 1.0806171450363893:
# 5
# Recommendations for Forrest Gump (1994):
#
# 1: Life Is Beautiful (La Vita è bella) (1997), with distance of 0.7840616263799309:
# 2: 400 Blows, The (Les quatre cents coups) (1959), with distance of 0.8796605429040171:
# 3: Short Term 12 (2013), with distance of 0.9099182966799484:
# 4: Paddington (2014), with distance of 1.120787769035809:
# 5: The Hateful Eight (2015), with distance of 1.1297590984890802:
